# %%
import wikipedia

# %%
pip install wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikipediaapi

# Wikipedia API nesnesini oluşturuyoruz
wiki_wiki = wikipediaapi.Wikipedia(user_agent="MyApp/1.0 (myemail@example.com)", language="en")

# 📌 Mevcut sanatçılar + Yeni eklenen sanatçılar
sanatci_listesi = {
    "Frida Kahlo": wiki_wiki.page("Frida_Kahlo").text,
    "Leonardo da Vinci": wiki_wiki.page("Leonardo_da_Vinci").text,
    "Vincent van Gogh": wiki_wiki.page("Vincent_van_Gogh").text,
    "Pablo Picasso": wiki_wiki.page("Pablo_Picasso").text,
    "Andy Warhol": wiki_wiki.page("Andy_Warhol").text,
    "Salvador Dalí": wiki_wiki.page("Salvador_Dalí").text,
    "Osman Hamdi Bey": wiki_wiki.page("Osman_Hamdi_Bey").text,
    "Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
    "Barbara Kruger": wiki_wiki.page("Barbara_Kruger").text,
    "Michelangelo": wiki_wiki.page("Michelangelo").text,
    "Raphael": wiki_wiki.page("Raphael").text,
    "Caravaggio": wiki_wiki.page("Caravaggio").text,
    "Rembrandt": wiki_wiki.page("Rembrandt").text,
    "Francisco Goya": wiki_wiki.page("Francisco_Goya").text,
    "Eugène Delacroix": wiki_wiki.page("Eugène_Delacroix").text,
    "Claude Monet": wiki_wiki.page("Claude_Monet").text,
    "Édouard Manet": wiki_wiki.page("Édouard_Manet").text,
    "Edgar Degas": wiki_wiki.page("Edgar_Degas").text,
    "Paul Cézanne": wiki_wiki.page("Paul_Cézanne").text,
    "Paul Gauguin": wiki_wiki.page("Paul_Gauguin").text,
    "Henri Matisse": wiki_wiki.page("Henri_Matisse").text,
    "Georges Braque": wiki_wiki.page("Georges_Braque").text,
    "René Magritte": wiki_wiki.page("René_Magritte").text,
    "Marc Chagall": wiki_wiki.page("Marc_Chagall").text,
    "Jackson Pollock": wiki_wiki.page("Jackson_Pollock").text,
    "Jean-Michel Basquiat": wiki_wiki.page("Jean-Michel_Basquiat").text,
    "Keith Haring": wiki_wiki.page("Keith_Haring").text,
    "Damien Hirst": wiki_wiki.page("Damien_Hirst").text,
    "Ai Weiwei": wiki_wiki.page("Ai_Weiwei").text,
    "Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
    "Jeff Koons": wiki_wiki.page("Jeff_Koons").text,
    "Jenny Holzer": wiki_wiki.page("Jenny_Holzer").text,
    "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "Georgia O'Keeffe": wiki_wiki.page("Georgia_O'Keeffe").text,
    "Louise Bourgeois": wiki_wiki.page("Louise_Bourgeois").text,
    "Cindy Sherman": wiki_wiki.page("Cindy_Sherman").text,
    "Tracey Emin": wiki_wiki.page("Tracey_Emin").text,
    "Kara Walker": wiki_wiki.page("Kara_Walker").text,
    "Judy Chicago": wiki_wiki.page("Judy_Chicago").text,
    "Artemisia Gentileschi": wiki_wiki.page("Artemisia_Gentileschi").text,
    "Hale Asaf": wiki_wiki.page("Hale_Asaf").text,
    "İbrahim Çallı": wiki_wiki.page("İbrahim_Çallı").text,
    "Abidin Dino": wiki_wiki.page("Abidin_Dino").text,
    "Erol Akyavaş": wiki_wiki.page("Erol_Akyavaş").text,
    "Nuri İyem": wiki_wiki.page("Nuri_İyem").text,
    "Fahrelnissa Zeid": wiki_wiki.page("Fahrelnissa_Zeid").text,
    "Neşet Günal": wiki_wiki.page("Neşet_Günal").text,
    "Burhan Doğançay": wiki_wiki.page("Burhan_Doğançay").text,
    "Gülsün Karamustafa": wiki_wiki.page("Gülsün_Karamustafa").text,
    "Sandro Botticelli": wiki_wiki.page("Sandro_Botticelli").text,
    "Albrecht Dürer": wiki_wiki.page("Albrecht_Dürer").text,
    "Jan van Eyck": wiki_wiki.page("Jan_van_Eyck").text,
    "Hieronymus Bosch": wiki_wiki.page("Hieronymus_Bosch").text,
    "Diego Velázquez": wiki_wiki.page("Diego_Velázquez").text,
    "El Greco": wiki_wiki.page("El_Greco").text,
    "Gustav Klimt": wiki_wiki.page("Gustav_Klimt").text,
    "Edvard Munch": wiki_wiki.page("Edvard_Munch").text,
    "Camille Pissarro": wiki_wiki.page("Camille_Pissarro").text,
"Giorgio de Chirico": wiki_wiki.page("Giorgio_de_Chirico").text,
"Umberto Boccioni": wiki_wiki.page("Umberto_Boccioni").text,
"Giotto di Bondone": wiki_wiki.page("Giotto_di_Bondone").text,
"Titian": wiki_wiki.page("Titian").text,
"Tintoretto": wiki_wiki.page("Tintoretto").text,
"Pieter Bruegel the Elder": wiki_wiki.page("Pieter_Bruegel_the_Elder").text,
"William Blake": wiki_wiki.page("William_Blake").text,
"Thomas Gainsborough": wiki_wiki.page("Thomas_Gainsborough").text,
"John Constable": wiki_wiki.page("John_Constable").text,
"J.M.W. Turner": wiki_wiki.page("J._M._W._Turner").text,
"Edwin Landseer": wiki_wiki.page("Edwin_Landseer").text,
"Eugène Boudin": wiki_wiki.page("Eugène_Boudin").text,
"Gustave Courbet": wiki_wiki.page("Gustave_Courbet").text,
"Jean-François Millet": wiki_wiki.page("Jean-François_Millet").text,
"Jules Bastien-Lepage": wiki_wiki.page("Jules_Bastien-Lepage").text,
"Henri Rousseau": wiki_wiki.page("Henri_Rousseau").text,
"Amedeo Modigliani": wiki_wiki.page("Amedeo_Modigliani").text,
"Egon Schiele": wiki_wiki.page("Egon_Schiele").text,
"Otto Dix": wiki_wiki.page("Otto_Dix").text,
"Max Ernst": wiki_wiki.page("Max_Ernst").text,
"Joan Miró": wiki_wiki.page("Joan_Miró").text,
"Kazimir Malevich": wiki_wiki.page("Kazimir_Malevich").text,
"Wassily Kandinsky": wiki_wiki.page("Wassily_Kandinsky").text,
"Piet Mondrian": wiki_wiki.page("Piet_Mondrian").text,
"Theo van Doesburg": wiki_wiki.page("Theo_van_Doesburg").text,
"László Moholy-Nagy": wiki_wiki.page("László_Moholy-Nagy").text,
"Joseph Beuys": wiki_wiki.page("Joseph_Beuys").text,
"Anselm Kiefer": wiki_wiki.page("Anselm_Kiefer").text,
"Gerhard Richter": wiki_wiki.page("Gerhard_Richter").text,
"Lucian Freud": wiki_wiki.page("Lucian_Freud").text,
"Francis Bacon": wiki_wiki.page("Francis_Bacon_(artist)").text,
"David Hockney": wiki_wiki.page("David_Hockney").text,
"Bridget Riley": wiki_wiki.page("Bridget_Riley").text,
"Richard Hamilton": wiki_wiki.page("Richard_Hamilton_(artist)").text,
"Peter Blake": wiki_wiki.page("Peter_Blake_(artist)").text,
"Banksy": wiki_wiki.page("Banksy").text,
"Shepard Fairey": wiki_wiki.page("Shepard_Fairey").text,
"Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
"Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
"Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
"Bill Viola": wiki_wiki.page("Bill_Viola").text,
"Nam June Paik": wiki_wiki.page("Nam_June_Paik").text,
"Jenny Saville": wiki_wiki.page("Jenny_Saville").text,
"Tracey Moffatt": wiki_wiki.page("Tracey_Moffatt").text,
"Julie Mehretu": wiki_wiki.page("Julie_Mehretu").text,
"Wangechi Mutu": wiki_wiki.page("Wangechi_Mutu").text,
"Kehinde Wiley": wiki_wiki.page("Kehinde_Wiley").text,
"Njideka Akunyili Crosby": wiki_wiki.page("Njideka_Akunyili_Crosby").text,
"Do Ho Suh": wiki_wiki.page("Do_Ho_Suh").text,
"Chiharu Shiota": wiki_wiki.page("Chiharu_Shiota").text,
"Tatsuo Miyajima": wiki_wiki.page("Tatsuo_Miyajima").text,
"Rirkrit Tiravanija": wiki_wiki.page("Rirkrit_Tiravanija").text,
"Tino Sehgal": wiki_wiki.page("Tino_Sehgal").text,
"Thomas Hirschhorn": wiki_wiki.page("Thomas_Hirschhorn").text,
"Wolfgang Tillmans": wiki_wiki.page("Wolfgang_Tillmans").text,
"Andreas Gursky": wiki_wiki.page("Andreas_Gursky").text,
"Thomas Struth": wiki_wiki.page("Thomas_Struth").text,
"Jeff Wall": wiki_wiki.page("Jeff_Wall").text,
"Cindy Sherman": wiki_wiki.page("Cindy_Sherman").text,
"Nan Goldin": wiki_wiki.page("Nan_Goldin").text,
"Barbara Kruger": wiki_wiki.page("Barbara_Kruger").text,
"Sarah Lucas": wiki_wiki.page("Sarah_Lucas").text,
"Cornelia Parker": wiki_wiki.page("Cornelia_Parker").text,
"Grayson Perry": wiki_wiki.page("Grayson_Perry").text,
"Gilbert & George": wiki_wiki.page("Gilbert_%26_George").text,
"Olafur Eliasson": wiki_wiki.page("Olafur_Eliasson").text,
"James Turrell": wiki_wiki.page("James_Turrell").text,
"Dan Flavin": wiki_wiki.page("Dan_Flavin").text,
"Donald Judd": wiki_wiki.page("Donald_Judd").text,
"Sol LeWitt": wiki_wiki.page("Sol_LeWitt").text,
"Robert Smithson": wiki_wiki.page("Robert_Smithson").text,
"Walter De Maria": wiki_wiki.page("Walter_De_Maria").text,
"Richard Serra": wiki_wiki.page("Richard_Serra").text,
"Christo and Jeanne-Claude": wiki_wiki.page("Christo_and_Jeanne-Claude").text,
"Jenny Holzer": wiki_wiki.page("Jenny_Holzer").text,
"Louise Nevelson": wiki_wiki.page("Louise_Nevelson").text,
"Eva Hesse": wiki_wiki.page("Eva_Hesse").text,
"Ana Mendieta": wiki_wiki.page("Ana_Mendieta").text,
"Marisol Escobar": wiki_wiki.page("Marisol_Escobar").text,
"Betye Saar": wiki_wiki.page("Betye_Saar").text,
"Faith Ringgold": wiki_wiki.page("Faith_Ringgold").text,
"Kara Walker": wiki_wiki.page("Kara_Walker").text,
"Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
"Mickalene Thomas": wiki_wiki.page("Mickalene_Thomas").text,
"Swoon": wiki_wiki.page("Swoon_(artist)").text,
"Barbara Hepworth": wiki_wiki.page("Barbara_Hepworth").text,
"Henry Moore": wiki_wiki.page("Henry_Moore").text,
"Isamu Noguchi": wiki_wiki.page("Isamu_Noguchi").text,
"Constantin Brâncuși": wiki_wiki.page("Constantin_Brâncuși").text,
"Jean Arp": wiki_wiki.page("Jean_Arp").text,
"Alberto Giacometti": wiki_wiki.page("Alberto_Giacometti").text,
"Claes Oldenburg": wiki_wiki.page("Claes_Oldenburg").text,
"George Segal": wiki_wiki.page("George_Segal_(artist)").text,
"Duane Hanson": wiki_wiki.page("Duane_Hanson").text,
"Ron Mueck": wiki_wiki.page("Ron_Mueck").text,
"Rachel Whiteread": wiki_wiki.page("Rachel_Whiteread").text,
"Antony Gormley": wiki_wiki.page("Antony_Gormley").text,
"Anish Kapoor": wiki_wiki.page("Anish_Kapoor").text,
"Niki de Saint Phalle": wiki_wiki.page("Niki_de_Saint_Phalle").text,
"Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
"Louise Bourgeois": wiki_wiki.page("Louise_Bourgeois").text,
"Hieronymus Bosch": wiki_wiki.page("Hieronymus_Bosch").text,
"Caravaggio": wiki_wiki.page("Caravaggio").text,
"Artemisia Gentileschi": wiki_wiki.page("Artemisia_Gentileschi").text,
"Giovanni Battista Tiepolo": wiki_wiki.page("Giovanni_Battista_Tiepolo").text,
"Jean Auguste Dominique Ingres": wiki_wiki.page("Jean_Auguste_Dominique_Ingres").text,
"Eugène Delacroix": wiki_wiki.page("Eugène_Delacroix").text,
"Gustave Moreau": wiki_wiki.page("Gustave_Moreau").text,
"Odilon Redon": wiki_wiki.page("Odilon_Redon").text,
"Félicien Rops": wiki_wiki.page("Félicien_Rops").text,
"Aubrey Beardsley": wiki_wiki.page("Aubrey_Beardsley").text,
"Käthe Kollwitz": wiki_wiki.page("Käthe_Kollwitz").text,
"Egon Schiele": wiki_wiki.page("Egon_Schiele").text,
"Oskar Kokoschka": wiki_wiki.page("Oskar_Kokoschka").text,
"Paula Modersohn-Becker": wiki_wiki.page("Paula_Modersohn-Becker").text,
"Gabriele Münter": wiki_wiki.page("Gabriele_Münter").text,
"Franz Marc": wiki_wiki.page("Franz_Marc").text,
"August Macke": wiki_wiki.page("August_Macke").text,
"Ernst Ludwig Kirchner": wiki_wiki.page("Ernst_Ludwig_Kirchner").text,
"Emil Nolde": wiki_wiki.page("Emil_Nolde").text,
"Max Beckmann": wiki_wiki.page("Max_Beckmann").text,
"Lyonel Feininger": wiki_wiki.page("Lyonel_Feininger").text,
"George Grosz": wiki_wiki.page("George_Grosz").text,
"Otto Mueller": wiki_wiki.page("Otto_Mueller").text,
"Christian Schad": wiki_wiki.page("Christian_Schad").text,
"Hans Bellmer": wiki_wiki.page("Hans_Bellmer").text,
"Balthus": wiki_wiki.page("Balthus").text,
"Felix Vallotton": wiki_wiki.page("Felix_Vallotton").text,
"Théophile Steinlen": wiki_wiki.page("Théophile_Steinlen").text,
"Henri de Toulouse-Lautrec": wiki_wiki.page("Henri_de_Toulouse-Lautrec").text,
"Alphonse Mucha": wiki_wiki.page("Alphonse_Mucha").text,
"Koloman Moser": wiki_wiki.page("Koloman_Moser").text,
"Gustav Klimt": wiki_wiki.page("Gustav_Klimt").text,
"John Singer Sargent": wiki_wiki.page("John_Singer_Sargent").text,
"James McNeill Whistler": wiki_wiki.page("James_McNeill_Whistler").text,
"Thomas Eakins": wiki_wiki.page("Thomas_Eakins").text,
"Winslow Homer": wiki_wiki.page("Winslow_Homer").text,
"Mary Cassatt": wiki_wiki.page("Mary_Cassatt").text,
"George Bellows": wiki_wiki.page("George_Bellows").text,
"Edward Hopper": wiki_wiki.page("Edward_Hopper").text,
"Charles Demuth": wiki_wiki.page("Charles_Demuth").text,
"Charles Sheeler": wiki_wiki.page("Charles_Sheeler").text,
"Georgia O'Keeffe": wiki_wiki.page("Georgia_O'Keeffe").text,
"Marsden Hartley": wiki_wiki.page("Marsden_Hartley").text,
"Arthur Dove": wiki_wiki.page("Arthur_Dove").text,
"Milton Avery": wiki_wiki.page("Milton_Avery").text,
"Jacob Lawrence": wiki_wiki.page("Jacob_Lawrence").text,
"Romare Bearden": wiki_wiki.page("Romare_Bearden").text,
"Horace Pippin": wiki_wiki.page("Horace_Pippin").text,
"Archibald Motley": wiki_wiki.page("Archibald_Motley").text,
"Aaron Douglas": wiki_wiki.page("Aaron_Douglas").text,
"Alma Thomas": wiki_wiki.page("Alma_Thomas").text,
"Norman Lewis": wiki_wiki.page("Norman_Lewis").text,
"Jean-Michel Basquiat": wiki_wiki.page("Jean-Michel_Basquiat").text,
"Kerry James Marshall": wiki_wiki.page("Kerry_James_Marshall").text,
"Beauford Delaney": wiki_wiki.page("Beauford_Delaney").text,
"Loïs Mailou Jones": wiki_wiki.page("Loïs_Mailou_Jones").text,
"William H. Johnson": wiki_wiki.page("William_H._Johnson").text,
"Henry Ossawa Tanner": wiki_wiki.page("Henry_Ossawa_Tanner").text,
"Elizabeth Catlett": wiki_wiki.page("Elizabeth_Catlett").text,
"Augusta Savage": wiki_wiki.page("Augusta_Savage").text,
"Selma Burke": wiki_wiki.page("Selma_Burke").text,
"Meta Vaux Warrick Fuller": wiki_wiki.page("Meta_Vaux_Warrick_Fuller").text,
"Faith Ringgold": wiki_wiki.page("Faith_Ringgold").text,
"Kara Walker": wiki_wiki.page("Kara_Walker").text,
"Mickalene Thomas": wiki_wiki.page("Mickalene_Thomas").text,
"Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
"Howardena Pindell": wiki_wiki.page("Howardena_Pindell").text,
"Betye Saar": wiki_wiki.page("Betye_Saar").text,
"Lubaina Himid": wiki_wiki.page("Lubaina_Himid").text,
"Chris Ofili": wiki_wiki.page("Chris_Ofili").text,
"Yinka Shonibare": wiki_wiki.page("Yinka_Shonibare").text,
"Zanele Muholi": wiki_wiki.page("Zanele_Muholi").text,
"Wangechi Mutu": wiki_wiki.page("Wangechi_Mutu").text,
"Njideka Akunyili Crosby": wiki_wiki.page("Njideka_Akunyili_Crosby").text,
"El Anatsui": wiki_wiki.page("El_Anatsui").text,
"Ibrahim Mahama": wiki_wiki.page("Ibrahim_Mahama").text,
"Mohau Modisakeng": wiki_wiki.page("Mohau_Modisakeng").text,
"Mary Sibande": wiki_wiki.page("Mary_Sibande").text,
"Sokari Douglas Camp": wiki_wiki.page("Sokari_Douglas_Camp").text,
"Romuald Hazoumè": wiki_wiki.page("Romuald_Hazoumè").text,
"Gonçalo Mabunda": wiki_wiki.page("Gonçalo_Mabunda").text,
"Zarouhie Abdalian": wiki_wiki.page("Zarouhie_Abdalian").text,
"Walid Raad": wiki_wiki.page("Walid_Raad").text,
"Akram Zaatari": wiki_wiki.page("Akram_Zaatari").text,
"Mona Hatoum": wiki_wiki.page("Mona_Hatoum").text,
"Emily Jacir": wiki_wiki.page("Emily_Jacir").text,
"Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
"Lalla Essaydi": wiki_wiki.page("Lalla_Essaydi").text,
"Manal AlDowayan": wiki_wiki.page("Manal_AlDowayan").text,
"Ghada Amer": wiki_wiki.page("Ghada_Amer").text,
"Zineb Sedira": wiki_wiki.page("Zineb_Sedira").text,
"Kader Attia": wiki_wiki.page("Kader_Attia").text,
"Yto Barrada": wiki_wiki.page("Yto_Barrada").text,
"M’barek Bouhchichi": wiki_wiki.page("M’barek_Bouhchichi").text,
"Joana Choumali": wiki_wiki.page("Joana_Choumali").text,
"Chéri Samba": wiki_wiki.page("Chéri_Samba").text,
"Frédéric Bruly Bouabré": wiki_wiki.page("Frédéric_Bruly_Bouabré").text,
"Bodys Isek Kingelez": wiki_wiki.page("Bodys_Isek_Kingelez").text,
"Abdoulaye Konaté": wiki_wiki.page("Abdoulaye_Konaté").text,
"Ouattara Watts": wiki_wiki.page("Ouattara_Watts").text,
"Ablade Glover": wiki_wiki.page("Ablade_Glover").text,
"Sue Williamson": wiki_wiki.page("Sue_Williamson").text,
"Willie Bester": wiki_wiki.page("Willie_Bester").text,
"Jane Alexander": wiki_wiki.page("Jane_Alexander_(artist)").text,
"Tracey Rose": wiki_wiki.page("Tracey_Rose").text,
"Zanele Muholi": wiki_wiki.page("Zanele_Muholi").text,
"Gerhard Richter": wiki_wiki.page("Gerhard_Richter").text,
"Anselm Kiefer": wiki_wiki.page("Anselm_Kiefer").text,
"Sigmar Polke": wiki_wiki.page("Sigmar_Polke").text,
"Neo Rauch": wiki_wiki.page("Neo_Rauch").text,
"Georg Baselitz": wiki_wiki.page("Georg_Baselitz").text,
"Martin Kippenberger": wiki_wiki.page("Martin_Kippenberger").text,
"Rosemarie Trockel": wiki_wiki.page("Rosemarie_Trockel").text,
"Rebecca Horn": wiki_wiki.page("Rebecca_Horn").text,
"Thomas Demand": wiki_wiki.page("Thomas_Demand").text,
"Thomas Struth": wiki_wiki.page("Thomas_Struth").text,
"Andreas Gursky": wiki_wiki.page("Andreas_Gursky").text,
"Candida Höfer": wiki_wiki.page("Candida_Höfer").text,
"Bernd and Hilla Becher": wiki_wiki.page("Bernd_and_Hilla_Becher").text,
"Nam June Paik": wiki_wiki.page("Nam_June_Paik").text,
"Shigeko Kubota": wiki_wiki.page("Shigeko_Kubota").text,
"Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
"Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
"Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
"Yoshitomo Nara": wiki_wiki.page("Yoshitomo_Nara").text,
"Mariko Mori": wiki_wiki.page("Mariko_Mori").text,
"Hiroshi Sugimoto": wiki_wiki.page("Hiroshi_Sugimoto").text,
"Daido Moriyama": wiki_wiki.page("Daido_Moriyama").text,
"Kenji Yanobe": wiki_wiki.page("Kenji_Yanobe").text,
"Chiharu Shiota": wiki_wiki.page("Chiharu_Shiota").text,
"Lee Ufan": wiki_wiki.page("Lee_Ufan").text,
"Kimsooja": wiki_wiki.page("Kimsooja").text,
"Do Ho Suh": wiki_wiki.page("Do_Ho_Suh").text,
"Nam Hye-Ri": wiki_wiki.page("Nam_Hye-Ri").text,
"Yang Fudong": wiki_wiki.page("Yang_Fudong").text,
"Zhang Huan": wiki_wiki.page("Zhang_Huan").text,
"Yue Minjun": wiki_wiki.page("Yue_Minjun").text,
"Zeng Fanzhi": wiki_wiki.page("Zeng_Fanzhi").text,
"Fang Lijun": wiki_wiki.page("Fang_Lijun").text,
"Xu Bing": wiki_wiki.page("Xu_Bing").text,
"Wu Guanzhong": wiki_wiki.page("Wu_Guanzhong").text,
"Cai Guo-Qiang": wiki_wiki.page("Cai_Guo-Qiang").text,
"Ai Weiwei": wiki_wiki.page("Ai_Weiwei").text,
"Huang Yong Ping": wiki_wiki.page("Huang_Yong_Ping").text,
"Gu Wenda": wiki_wiki.page("Gu_Wenda").text,
"Wang Guangyi": wiki_wiki.page("Wang_Guangyi").text,
"Wang Qingsong": wiki_wiki.page("Wang_Qingsong").text,
"Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
"Monir Shahroudy Farmanfarmaian": wiki_wiki.page("Monir_Shahroudy_Farmanfarmaian").text,
"Parviz Tanavoli": wiki_wiki.page("Parviz_Tanavoli").text,
"Reza Abbasi": wiki_wiki.page("Reza_Abbasi").text,
"Behjat Sadr": wiki_wiki.page("Behjat_Sadr").text,
"Siah Armajani": wiki_wiki.page("Siah_Armajani").text,
"Farideh Lashai": wiki_wiki.page("Farideh_Lashai").text,
"Ali Banisadr": wiki_wiki.page("Ali_Banisadr").text,
"Nazgol Ansarinia": wiki_wiki.page("Nazgol_Ansarinia").text,
"Shadi Ghadirian": wiki_wiki.page("Shadi_Ghadirian").text,
"Zahra Eskandari": wiki_wiki.page("Zahra_Eskandari").text,
"Mehrdad Mohebali": wiki_wiki.page("Mehrdad_Mohebali").text,
"Ardeshir Mohassess": wiki_wiki.page("Ardeshir_Mohassess").text,
"Nicky Nodjoumi": wiki_wiki.page("Nicky_Nodjoumi").text,
"Bahman Mohasses": wiki_wiki.page("Bahman_Mohasses").text,
"Kamran Diba": wiki_wiki.page("Kamran_Diba").text,
"Chant Avedissian": wiki_wiki.page("Chant_Avedissian").text,
"Ghada Amer": wiki_wiki.page("Ghada_Amer").text,
"Hassan Khan": wiki_wiki.page("Hassan_Khan").text,
"Wael Shawky": wiki_wiki.page("Wael_Shawky").text,
"Mohamed Abla": wiki_wiki.page("Mohamed_Abla").text,
"Ahmed Morsi": wiki_wiki.page("Ahmed_Morsi").text,
"Huda Lutfi": wiki_wiki.page("Huda_Lutfi").text,
"Doaa El-Adl": wiki_wiki.page("Doaa_El-Adl").text,
"Fahrelnissa Zeid": wiki_wiki.page("Fahrelnissa_Zeid").text,
"İbrahim Çallı": wiki_wiki.page("İbrahim_Çallı").text,
"Bedri Rahmi Eyüboğlu": wiki_wiki.page("Bedri_Rahmi_Eyüboğlu").text,
"Fikret Mualla": wiki_wiki.page("Fikret_Mualla").text,
"Burhan Doğançay": wiki_wiki.page("Burhan_Doğançay").text,
"Abidin Dino": wiki_wiki.page("Abidin_Dino").text,
"Neşe Erdok": wiki_wiki.page("Neşe_Erdok").text,
"Mehmet Güleryüz": wiki_wiki.page("Mehmet_Güleryüz").text,
"Şükran Moral": wiki_wiki.page("Şükran_Moral").text,
"Taner Ceylan": wiki_wiki.page("Taner_Ceylan").text,
"Halil Altındere": wiki_wiki.page("Halil_Altındere").text,
"Canan Şenol": wiki_wiki.page("Canan_Şenol").text,
"Gülsün Karamustafa": wiki_wiki.page("Gülsün_Karamustafa").text,
"Ali Kazma": wiki_wiki.page("Ali_Kazma").text,
"Ahmet Öğüt": wiki_wiki.page("Ahmet_Öğüt").text,
"Hale Tenger": wiki_wiki.page("Hale_Tenger").text,
"Sarkis": wiki_wiki.page("Sarkis").text,
"Nil Yalter": wiki_wiki.page("Nil_Yalter").text,
"Kutluğ Ataman": wiki_wiki.page("Kutluğ_Ataman").text,
"Ergin Çavuşoğlu": wiki_wiki.page("Ergin_Çavuşoğlu").text,
"Hüseyin Bahri Alptekin": wiki_wiki.page("Hüseyin_Bahri_Alptekin").text,
"İnci Eviner": wiki_wiki.page("İnci_Eviner").text,
"Zehra Doğan": wiki_wiki.page("Zehra_Doğan").text,
"Bubi": wiki_wiki.page("Bubi_(artist)").text,
"Ekrem Kahraman": wiki_wiki.page("Ekrem_Kahraman").text,
"Devrim Erbil": wiki_wiki.page("Devrim_Erbil").text,
"Mustafa Ata": wiki_wiki.page("Mustafa_Ata").text,
"Erol Akyavaş": wiki_wiki.page("Erol_Akyavaş").text,
    "Osman Nuri Paşa": wiki_wiki.page("Osman_Nuri_Paşa").text,
"Ferik İbrahim Paşa": wiki_wiki.page("Ferik_İbrahim_Paşa").text,
"Osman Nuri Paşa": wiki_wiki.page("Osman_Nuri_Paşa").text,
"Şeker Ahmet Paşa": wiki_wiki.page("Şeker_Ahmet_Paşa").text,
"Halil Paşa": wiki_wiki.page("Halil_Paşa_(ressam)").text,
"Hoca Ali Rıza": wiki_wiki.page("Hoca_Ali_Rıza").text,
"İbrahim Çallı": wiki_wiki.page("İbrahim_Çallı").text,
"Avni Lifij": wiki_wiki.page("Avni_Lifij").text,
"Feyhaman Duran": wiki_wiki.page("Feyhaman_Duran").text,
"Namık İsmail": wiki_wiki.page("Namık_İsmail").text,
"Hikmet Onat": wiki_wiki.page("Hikmet_Onat").text,
"Ali Avni Çelebi": wiki_wiki.page("Ali_Avni_Çelebi").text,
"Mahmut Cuda": wiki_wiki.page("Mahmut_Cuda").text,
"Zeki Kocamemi": wiki_wiki.page("Zeki_Kocamemi").text,
"Bedri Rahmi Eyüboğlu": wiki_wiki.page("Bedri_Rahmi_Eyüboğlu").text,
"Nurullah Berk": wiki_wiki.page("Nurullah_Berk").text,
"Cemal Tollu": wiki_wiki.page("Cemal_Tollu").text,
"Abidin Dino": wiki_wiki.page("Abidin_Dino").text,
"Aliye Berger": wiki_wiki.page("Aliye_Berger").text,
"Fikret Mualla": wiki_wiki.page("Fikret_Mualla").text,
"Ferruh Başağa": wiki_wiki.page("Ferruh_Başağa").text,
"Adnan Çoker": wiki_wiki.page("Adnan_Çoker").text,
"Neşet Günal": wiki_wiki.page("Neşet_Günal").text,
"Ergin İnan": wiki_wiki.page("Ergin_İnan").text,
"Gülay Semercioğlu": wiki_wiki.page("Gülay_Semercioğlu").text,
"Ahmet Güneştekin": wiki_wiki.page("Ahmet_Güneştekin").text,
"Fahrelnissa Zeid": wiki_wiki.page("Fahrelnissa_Zeid").text,
"Şirin Devrim": wiki_wiki.page("Şirin_Devrim").text,
"Burcu Perçin": wiki_wiki.page("Burcu_Perçin").text,
"Eda Emirdağ": wiki_wiki.page("Eda_Emirdağ").text,
"Ali İsmail Turgut": wiki_wiki.page("Ali_İsmail_Turgut").text,
"Meltem Sırtıkara": wiki_wiki.page("Meltem_Sırtıkara").text,
"Seçkin Pirim": wiki_wiki.page("Seçkin_Pirim").text,
"Tunç Dindaş": wiki_wiki.page("Tunç_Dindaş").text,
"Nermin Er": wiki_wiki.page("Nermin_Er").text,
"Kürşat Kızbaz": wiki_wiki.page("Kürşat_Kızbaz").text,
"Hande Şekerciler": wiki_wiki.page("Hande_Şekerciler").text,
"Ardan Özmenoğlu": wiki_wiki.page("Ardan_Özmenoğlu").text,
"Hayal İncedoğan": wiki_wiki.page("Hayal_İncedoğan").text,
"Selma Gürbüz": wiki_wiki.page("Selma_Gürbüz").text,
"Genco Gülan": wiki_wiki.page("Genco_Gülan").text,
"Yüksel Arslan": wiki_wiki.page("Yüksel_Arslan").text,
"Mehmet Güleryüz": wiki_wiki.page("Mehmet_Güleryüz").text,
"Mübin Orhon": wiki_wiki.page("Mübin_Orhon").text,
"Utku Varlık": wiki_wiki.page("Utku_Varlık").text,
"Şükrü Aysan": wiki_wiki.page("Şükrü_Aysan").text,
"Ekrem Kahraman": wiki_wiki.page("Ekrem_Kahraman").text,
"Devrim Erbil": wiki_wiki.page("Devrim_Erbil").text,
"Tamer Başoğlu": wiki_wiki.page("Tamer_Başoğlu").text,
"Vural Arıkan": wiki_wiki.page("Vural_Arıkan").text,
"Yavuz Tanyeli": wiki_wiki.page("Yavuz_Tanyeli").text,
"Özdemir Altan": wiki_wiki.page("Özdemir_Altan").text,
"Adnan Varınca": wiki_wiki.page("Adnan_Varınca").text,
"Süleyman Saim Tekcan": wiki_wiki.page("Süleyman_Saim_Tekcan").text,
"Hasan Pekmezci": wiki_wiki.page("Hasan_Pekmezci").text,
"Mehmet Ali Doğan": wiki_wiki.page("Mehmet_Ali_Doğan").text,
"Bedri Baykam": wiki_wiki.page("Bedri_Baykam").text,
"Mustafa Ata": wiki_wiki.page("Mustafa_Ata").text,
"İlhan Koman": wiki_wiki.page("İlhan_Koman").text,
"Nermin Alpar": wiki_wiki.page("Nermin_Alpar").text,
"Osman Dinç": wiki_wiki.page("Osman_Dinç").text,
"Kürşad Tosun": wiki_wiki.page("Kürşad_Tosun").text,
"Nedret Sekban": wiki_wiki.page("Nedret_Sekban").text,
"Murat Pulat": wiki_wiki.page("Murat_Pulat").text,
"Taner Ceylan": wiki_wiki.page("Taner_Ceylan").text,
"Bubi": wiki_wiki.page("Bubi_(artist)").text,
"Ahmet Elhan": wiki_wiki.page("Ahmet_Elhan").text,
"Canan Tolon": wiki_wiki.page("Canan_Tolon").text,
"Ali Cabbar": wiki_wiki.page("Ali_Cabbar").text,
"Çağdaş Erçelik": wiki_wiki.page("Çağdaş_Erçelik").text,
"Hüseyin Arıcı": wiki_wiki.page("Hüseyin_Arıcı").text,
"Handan Börüteçene": wiki_wiki.page("Handan_Börüteçene").text,
"Canan Şenol": wiki_wiki.page("Canan_Şenol").text,
"Zehra Doğan": wiki_wiki.page("Zehra_Doğan").text,
"Necla Rüzgar": wiki_wiki.page("Necla_Rüzgar").text,
"Bahar Yürükoğlu": wiki_wiki.page("Bahar_Yürükoğlu").text,
"Serkan Demir": wiki_wiki.page("Serkan_Demir").text,
"Ali M. Demirel": wiki_wiki.page("Ali_M._Demirel").text,
"Funda İyce Tuncel": wiki_wiki.page("Funda_İyce_Tuncel").text,
"Emre Hüner": wiki_wiki.page("Emre_Hüner").text,
"Erdağ Aksel": wiki_wiki.page("Erdağ_Aksel").text,
"Burçak Bingöl": wiki_wiki.page("Burçak_Bingöl").text,
"Hera Büyüktaşçıyan": wiki_wiki.page("Hera_Büyüktaşçıyan").text,
"Rasim Aksan": wiki_wiki.page("Rasim_Aksan").text,
"Aslı Çavuşoğlu": wiki_wiki.page("Aslı_Çavuşoğlu").text,
"Yağız Özgen": wiki_wiki.page("Yağız_Özgen").text,
"İhsan Oturmak": wiki_wiki.page("İhsan_Oturmak").text,
"Nilbar Güreş": wiki_wiki.page("Nilbar_Güreş").text,
"Cevdet Erek": wiki_wiki.page("Cevdet_Erek").text,
"Irfan Önürmen": wiki_wiki.page("Irfan_Önürmen").text,
"Sibel Horada": wiki_wiki.page("Sibel_Horada").text,
"Ali Kazma": wiki_wiki.page("Ali_Kazma").text,
"Gülsün Karamustafa": wiki_wiki.page("Gülsün_Karamustafa").text,
"Taner Ceylan": wiki_wiki.page("Taner_Ceylan").text,
"Mert Alas": wiki_wiki.page("Mert_Alas").text,
"Vahap Avsar": wiki_wiki.page("Vahap_Avsar").text,
"Ayse Erkmen": wiki_wiki.page("Ayşe_Erkmen").text,
"Gulay Semercioglu": wiki_wiki.page("Gülay_Semercioglu").text,
"Tamer Nakisci": wiki_wiki.page("Tamer_Nakışçı").text,
"Pinar Yolacan": wiki_wiki.page("Pınar_Yolaçan").text,
"Nuri Kuzucan": wiki_wiki.page("Nuri_Kuzucan").text,
"Nil Yalter": wiki_wiki.page("Nil_Yalter").text,
"Cindy Sherman": wiki_wiki.page("Cindy_Sherman").text,
    "Georgia O'Keeffe": wiki_wiki.page("Georgia_O'Keeffe").text,
    "Artemisia Gentileschi": wiki_wiki.page("Artemisia_Gentileschi").text,
    "Louise Bourgeois": wiki_wiki.page("Louise_Bourgeois").text,
    "Tracey Emin": wiki_wiki.page("Tracey_Emin").text,
    "Kara Walker": wiki_wiki.page("Kara_Walker").text,
    "Jenny Holzer": wiki_wiki.page("Jenny_Holzer").text,
    "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "Judy Chicago": wiki_wiki.page("Judy_Chicago").text,
    "Helen Frankenthaler": wiki_wiki.page("Helen_Frankenthaler").text,
    "Martha Rosler": wiki_wiki.page("Martha_Rosler").text,
    "Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
    "Sophie Calle": wiki_wiki.page("Sophie_Calle").text,
    "Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
    "Nan Goldin": wiki_wiki.page("Nan_Goldin").text,
    "Tania Bruguera": wiki_wiki.page("Tania_Bruguera").text,
    "Zanele Muholi": wiki_wiki.page("Zanele_Muholi").text,
    "Judy Chicago": wiki_wiki.page("Judy_Chicago").text,
    "Eva Hesse": wiki_wiki.page("Eva_Hesse").text,
    "Kiki Smith": wiki_wiki.page("Kiki_Smith").text,
    "Maggie Nelson": wiki_wiki.page("Maggie_Nelson").text,
    "Rebecca Horn": wiki_wiki.page("Rebecca_Horn").text,
    "Nikki S. Lee": wiki_wiki.page("Nikki_S_Lee").text,
    "Betye Saar": wiki_wiki.page("Betye_Saar").text,
    "Michele Oka Doner": wiki_wiki.page("Michele_Oka_Doner").text,
    "Adriana Varejão": wiki_wiki.page("Adriana_Varejão").text,
    "Elizabeth Catlett": wiki_wiki.page("Elizabeth_Catlett").text,
    "Rachel Whiteread": wiki_wiki.page("Rachel_Whiteread").text,
    "Sandy Skoglund": wiki_wiki.page("Sandy_Skoglund").text,
    "Catherine Opie": wiki_wiki.page("Catherine_Opie").text,
    "Ellen Gallagher": wiki_wiki.page("Ellen_Gallagher").text,
    "Rosa Bonheur": wiki_wiki.page("Rosa_Bonheur").text,
    "Marie Laurencin": wiki_wiki.page("Marie_Laurencin").text,
    "Diane Arbus": wiki_wiki.page("Diane_Arbus").text,
    "Francesca Woodman": wiki_wiki.page("Francesca_Woodman").text,
    "Paula Rego": wiki_wiki.page("Paula_Rego").text,
    "Carolee Schneemann": wiki_wiki.page("Carolee_Schneemann").text,
    "Carmen L. Hernández": wiki_wiki.page("Carmen_L_Hernández").text,
    "Zoe Leonard": wiki_wiki.page("Zoe_Leonard").text,
    "Julie Mehretu": wiki_wiki.page("Julie_Mehretu").text,
    "Nari Ward": wiki_wiki.page("Nari_Ward").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Kirsten Justesen": wiki_wiki.page("Kirsten_Justesen").text,
    "Saskia Olde Wolbers": wiki_wiki.page("Saskia_Olde_Wolbers").text,
    "Helen Chadwick": wiki_wiki.page("Helen_Chadwick").text,
    "Sandy Brodsky": wiki_wiki.page("Sandy_Brodsky").text,
    "Nan Goldin": wiki_wiki.page("Nan_Goldin").text,
    "Hito Steyerl": wiki_wiki.page("Hito_Steyerl").text,
    "Liza Lou": wiki_wiki.page("Liza_Lou").text,
    "Zanele Muholi": wiki_wiki.page("Zanele_Muholi").text,
    "Miriam Schapiro": wiki_wiki.page("Miriam_Schapiro").text,
    "Megan Rooney": wiki_wiki.page("Megan_Rooney").text,
    "Catherine Opie": wiki_wiki.page("Catherine_Opie").text,
    "Nikki S. Lee": wiki_wiki.page("Nikki_S_Lee").text,
    "Ann Hamilton": wiki_wiki.page("Ann_Hamilton").text,
    "Johanna Billing": wiki_wiki.page("Johanna_Billing").text,
    "Megan O’Connell": wiki_wiki.page("Megan_OConnell").text,
    "Betty Tompkins": wiki_wiki.page("Betty_Tompkins").text,
    "Rachael Lee Hovnanian": wiki_wiki.page("Rachael_Lee_Hovnanian").text,
    "Ana Mendieta": wiki_wiki.page("Ana_Mendieta").text,
    "Faith Ringgold": wiki_wiki.page("Faith_Ringgold").text,
    "Betye Saar": wiki_wiki.page("Betye_Saar").text,
    "Martha Rosler": wiki_wiki.page("Martha_Rosler").text,
    "Sue Williams": wiki_wiki.page("Sue_Williams").text,
    "Taryn Simon": wiki_wiki.page("Taryn_Simon").text,
    "Dara Birnbaum": wiki_wiki.page("Dara_Birnbaum").text,
    "Annette Messager": wiki_wiki.page("Annette_Messager").text,
    "Jodie Carey": wiki_wiki.page("Jodie_Carey").text,
    "Monica Bonvicini": wiki_wiki.page("Monica_Bonvicini").text,
    "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "LaToya Ruby Frazier": wiki_wiki.page("LaToya_Ruby_Frazier").text,
    "Cecilia Vicuña": wiki_wiki.page("Cecilia_Vicuña").text,
    "Lynne Tillman": wiki_wiki.page("Lynne_Tillman").text,
    "Pipilotti Rist": wiki_wiki.page("Pipilotti_Rist").text,
    "Lydia Davis": wiki_wiki.page("Lydia_Davis").text,
    "Chantal Akerman": wiki_wiki.page("Chantal_Akerman").text,
    "Mona Hatoum": wiki_wiki.page("Mona_Hatoum").text,
    "Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
    "Mia Feuer": wiki_wiki.page("Mia_Feuer").text,
    "Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
    "Kimsooja": wiki_wiki.page("Kimsooja").text,
    "Jelena Jureša": wiki_wiki.page("Jelena_Jureša").text,
    "Eija-Liisa Ahtila": wiki_wiki.page("Eija_Liisa_Ahtila").text,
    "Loredana Nemes": wiki_wiki.page("Loredana_Nemes").text,
    "Zoe Leonard": wiki_wiki.page("Zoe_Leonard").text,
    "Julie Mehretu": wiki_wiki.page("Julie_Mehretu").text,
    "Nari Ward": wiki_wiki.page("Nari_Ward").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Kirsten Justesen": wiki_wiki.page("Kirsten_Justesen").text,
    "Saskia Olde Wolbers": wiki_wiki.page("Saskia_Olde_Wolbers").text,
    "Helen Chadwick": wiki_wiki.page("Helen_Chadwick").text,
    "Sandy Skoglund": wiki_wiki.page("Sandy_Skoglund").text,
        "Ava DuVernay": wiki_wiki.page("Ava_DuVernay").text,
    "Gloria Steinem": wiki_wiki.page("Gloria_Steinem").text,
    "Carmen L. Hernández": wiki_wiki.page("Carmen_L_Hernández").text,
    "Mia Farrow": wiki_wiki.page("Mia_Farrow").text,
    "Andrea Dworkin": wiki_wiki.page("Andrea_Dworkin").text,
    "Michelle Obama": wiki_wiki.page("Michelle_Obama").text,
    "Eve Ensler": wiki_wiki.page("Eve_Ensler").text,
    "Beyoncé": wiki_wiki.page("Beyoncé").text,
    "Solange Knowles": wiki_wiki.page("Solange_Knowles").text,
    "Janelle Monáe": wiki_wiki.page("Janelle_Monáe").text,
    "Laverne Cox": wiki_wiki.page("Laverne_Cox").text,
    "Emma Watson": wiki_wiki.page("Emma_Watson").text,
    "Audre Lorde": wiki_wiki.page("Audre_Lorde").text,
    "Angela Davis": wiki_wiki.page("Angela_Davis").text,
    "bell hooks": wiki_wiki.page("bell_hooks").text,
    "Rosa Parks": wiki_wiki.page("Rosa_Parks").text,
    "Maya Angelou": wiki_wiki.page("Maya_Angelou").text,
    "Dolores Huerta": wiki_wiki.page("Dolores_Huerta").text,
    "Lena Dunham": wiki_wiki.page("Lena_Dunham").text,
    "Sarah McBride": wiki_wiki.page("Sarah_McBride").text,
    "Rebecca Solnit": wiki_wiki.page("Rebecca_Solnit").text,
    "Shonda Rhimes": wiki_wiki.page("Shonda_Rhimes").text,
    "Judith Butler": wiki_wiki.page("Judith_Butler").text,
    "Martha Nussbaum": wiki_wiki.page("Martha_Nussbaum").text,
    "Patricia Hill Collins": wiki_wiki.page("Patricia_Hill_Collins").text,
    "Simone de Beauvoir": wiki_wiki.page("Simone_de_Beauvoir").text,
    "Germaine Greer": wiki_wiki.page("Germaine_Greer").text,
    "Barbara Smith": wiki_wiki.page("Barbara_Smith").text,
    "Mary Wollstonecraft": wiki_wiki.page("Mary_Wollstonecraft").text,
    "Kate Millett": wiki_wiki.page("Kate_Millett").text,
    "Toni Morrison": wiki_wiki.page("Toni_Morrison").text,
    "Zadie Smith": wiki_wiki.page("Zadie_Smith").text,
    "Joan Didion": wiki_wiki.page("Joan_Didion").text,
    "Hillary Clinton": wiki_wiki.page("Hillary_Clinton").text,
    "Caitlyn Jenner": wiki_wiki.page("Caitlyn_Jenner").text,
    "Patti Smith": wiki_wiki.page("Patti_Smith").text,
    "Grace Jones": wiki_wiki.page("Grace_Jones").text,
    "Debbie Harry": wiki_wiki.page("Debbie_Harry").text,
    "Lady Gaga": wiki_wiki.page("Lady_Gaga").text,
    "Madonna": wiki_wiki.page("Madonna").text,
    "Cher": wiki_wiki.page("Cher").text,
    "Kesha": wiki_wiki.page("Kesha").text,
    "Rihanna": wiki_wiki.page("Rihanna").text,
    "Nicki Minaj": wiki_wiki.page("Nicki_Minaj").text,
    "Alicia Keys": wiki_wiki.page("Alicia_Keys").text,
    "Lizzo": wiki_wiki.page("Lizzo").text,
    "Celine Dion": wiki_wiki.page("Celine_Dion").text,
    "Stevie Nicks": wiki_wiki.page("Stevie_Nicks").text,
    "Aretha Franklin": wiki_wiki.page("Aretha_Franklin").text,
    "Janet Jackson": wiki_wiki.page("Janet_Jackson").text,
    "Megan Thee Stallion": wiki_wiki.page("Megan_Thee_Stallion").text,
    "Cardi B": wiki_wiki.page("Cardi_B").text,
    "Brittney Griner": wiki_wiki.page("Brittney_Griner").text,
    "Kamala Harris": wiki_wiki.page("Kamala_Harris").text,
    "Michelle Alexander": wiki_wiki.page("Michelle_Alexander").text,
    "Tara Westover": wiki_wiki.page("Tara_Westover").text,
    "Megan Rapinoe": wiki_wiki.page("Megan_Rapinoe").text,
    "Alicia Garza": wiki_wiki.page("Alicia_Garza").text,
    "Patrisse Cullors": wiki_wiki.page("Patrisse_Cullors").text,
    "Opal Tometi": wiki_wiki.page("Opal_Tometi").text,
    "Tarana Burke": wiki_wiki.page("Tarana_Burke").text,
    "Ruth Bader Ginsburg": wiki_wiki.page("Ruth_Bader_Ginsburg").text,
    "Sonia Sotomayor": wiki_wiki.page("Sonia_Sotomayor").text,
    "Sandra Day O'Connor": wiki_wiki.page("Sandra_Day_OConnor").text,
    "Gloria Anzaldúa": wiki_wiki.page("Gloria_Anzaldúa").text,
    "Alice Walker": wiki_wiki.page("Alice_Walker").text,
    "Frances Beal": wiki_wiki.page("Frances_Beal").text,
    "Alicia Keys": wiki_wiki.page("Alicia_Keys").text,
    "Georgia O'Keeffe": wiki_wiki.page("Georgia_O'Keeffe").text,
    "Louise Bourgeois": wiki_wiki.page("Louise_Bourgeois").text,
    "Artemisia Gentileschi": wiki_wiki.page("Artemisia_Gentileschi").text,
    "Maggie Hambling": wiki_wiki.page("Maggie_Hambling").text,
    "Helen Chadwick": wiki_wiki.page("Helen_Chadwick").text,
    "Nina Simone": wiki_wiki.page("Nina_Simone").text,
    "Elizabeth Catlett": wiki_wiki.page("Elizabeth_Catlett").text,
    "Kiki Smith": wiki_wiki.page("Kiki_Smith").text,
    "Miriam Schapiro": wiki_wiki.page("Miriam_Schapiro").text,
    "Eva Hesse": wiki_wiki.page("Eva_Hesse").text,
    "Gina Pane": wiki_wiki.page("Gina_Pane").text,
    "Fayçal Baghriche": wiki_wiki.page("Fayçal_Baghriche").text,
    "Monica Bonvicini": wiki_wiki.page("Monica_Bonvicini").text,
    "Jenny Holzer": wiki_wiki.page("Jenny_Holzer").text,
    "Catherine Opie": wiki_wiki.page("Catherine_Opie").text,
    "Nan Goldin": wiki_wiki.page("Nan_Goldin").text,
    "Ruth Asawa": wiki_wiki.page("Ruth_Asawa").text,
    "Patricia Cronin": wiki_wiki.page("Patricia_Cronin").text,
    "Berenice Abbott": wiki_wiki.page("Berenice_Abbott").text,
    "Sophie Calle": wiki_wiki.page("Sophie_Calle").text,
    "Mickalene Thomas": wiki_wiki.page("Mickalene_Thomas").text,
    "Francesca Woodman": wiki_wiki.page("Francesca_Woodman").text,
    "Chantal Akerman": wiki_wiki.page("Chantal_Akerman").text,
    "Barbara Kruger": wiki_wiki.page("Barbara_Kruger").text,
    "Joan Mitchell": wiki_wiki.page("Joan_Mitchell").text,
    "Sarah Lucas": wiki_wiki.page("Sarah_Lucas").text,
    "Hannah Wilke": wiki_wiki.page("Hannah_Wilke").text,
    "Sandy Skoglund": wiki_wiki.page("Sandy_Skoglund").text,
    "Tania Bruguera": wiki_wiki.page("Tania_Bruguera").text,
    "Ghada Amer": wiki_wiki.page("Ghada_Amer").text,
    "Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
    "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "Barbara Hepworth": wiki_wiki.page("Barbara_Hepworth").text,
    "Elisabeth Louise Vigée Le Brun": wiki_wiki.page("Elisabeth_Louise_Vigée_Le_Brun").text,
    "Mariko Mori": wiki_wiki.page("Mariko_Mori").text,
    "Berenice Abbott": wiki_wiki.page("Berenice_Abbott").text,
    "Judy Chicago": wiki_wiki.page("Judy_Chicago").text,
    "Sue Williams": wiki_wiki.page("Sue_Williams").text,
    "Eva Jospin": wiki_wiki.page("Eva_Jospin").text,
    "Phyllida Barlow": wiki_wiki.page("Phyllida_Barlow").text,
    "Louise Nevelson": wiki_wiki.page("Louise_Nevelson").text,
    "Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
    "Deborah Kass": wiki_wiki.page("Deborah_Kass").text,
    "Judy Pfaff": wiki_wiki.page("Judy_Pfaff").text,
    "Lee Krasner": wiki_wiki.page("Lee_Krasner").text,
    "Beatriz Milhazes": wiki_wiki.page("Beatriz_Milhazes").text,
    "Monique Prieto": wiki_wiki.page("Monique_Prieto").text,
    "Lucian Freud": wiki_wiki.page("Lucian_Freud").text,
    "Francesco Clemente": wiki_wiki.page("Francesco_Clemente").text,
    "Anni Albers": wiki_wiki.page("Anni_Albers").text,
    "Patty Jenkins": wiki_wiki.page("Patty_Jenkins").text,
    "Rashid Johnson": wiki_wiki.page("Rashid_Johnson").text,
    "Amy Sherald": wiki_wiki.page("Amy_Sherald").text,
    "Janelle Monáe": wiki_wiki.page("Janelle_Monáe").text,
    "Alice Neel": wiki_wiki.page("Alice_Neel").text,
    "Carrie Mae Weems": wiki_wiki.page("Carrie_Mae_Weems").text,
    "Alma Thomas": wiki_wiki.page("Alma_Thomas").text,
    "Doris Salcedo": wiki_wiki.page("Doris_Salcedo").text,
    "Kimsooja": wiki_wiki.page("Kimsooja").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Joan Baez": wiki_wiki.page("Joan_Baez").text,
    "Marlene Dumas": wiki_wiki.page("Marlene_Dumas").text,
    "Mona Hatoum": wiki_wiki.page("Mona_Hatoum").text,
    "Barbara Kruger": wiki_wiki.page("Barbara_Kruger").text,
    "Tanya Bruguera": wiki_wiki.page("Tania_Bruguera").text,
    "Meret Oppenheim": wiki_wiki.page("Meret_Oppenheim").text,
    "Carolee Schneemann": wiki_wiki.page("Carolee_Schneemann").text,
    "Lorna Simpson": wiki_wiki.page("Lorna_Simpson").text,
    "Nancy Spero": wiki_wiki.page("Nancy_Spero").text,
    "Maya Lin": wiki_wiki.page("Maya_Lin").text,
    "Eva Hesse": wiki_wiki.page("Eva_Hesse").text,
    "Hilma af Klint": wiki_wiki.page("Hilma_af_Klint").text,
    "Martha Rosler": wiki_wiki.page("Martha_Rosler").text,
    "Nan Goldin": wiki_wiki.page("Nan_Goldin").text,
    "Mickalene Thomas": wiki_wiki.page("Mickalene_Thomas").text,
    "Kara Walker": wiki_wiki.page("Kara_Walker").text,
    "Sophie Calle": wiki_wiki.page("Sophie_Calle").text,
    "Francesca Woodman": wiki_wiki.page("Francesca_Woodman").text,
    "Judy Chicago": wiki_wiki.page("Judy_Chicago").text,
    "Jenny Holzer": wiki_wiki.page("Jenny_Holzer").text,
    "Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
    "Tracey Emin": wiki_wiki.page("Tracey_Emin").text,
    "Kiki Smith": wiki_wiki.page("Kiki_Smith").text,
    "Cindy Sherman": wiki_wiki.page("Cindy_Sherman").text,
    "Dorothea Tanning": wiki_wiki.page("Dorothea_Tanning").text,
    "Lynn Hershman Leeson": wiki_wiki.page("Lynn_Hershman_Leeson").text,
    "Tina Modotti": wiki_wiki.page("Tina_Modotti").text,
    "Maggie Hambling": wiki_wiki.page("Maggie_Hambling").text,
    "Gina Pane": wiki_wiki.page("Gina_Pane").text,
    "Ruth Asawa": wiki_wiki.page("Ruth_Asawa").text,
    "Helen Chadwick": wiki_wiki.page("Helen_Chadwick").text,
    "Barbara Hepworth": wiki_wiki.page("Barbara_Hepworth").text,
    "Elisabeth Louise Vigée Le Brun": wiki_wiki.page("Elisabeth_Louise_Vigée_Le_Brun").text,
    "Miriam Schapiro": wiki_wiki.page("Miriam_Schapiro").text,
    "Monica Bonvicini": wiki_wiki.page("Monica_Bonvicini").text,
    "Sandy Skoglund": wiki_wiki.page("Sandy_Skoglund").text,
    "Patricia Cronin": wiki_wiki.page("Patricia_Cronin").text,
    "Deborah Kass": wiki_wiki.page("Deborah_Kass").text,
    "Phyllida Barlow": wiki_wiki.page("Phyllida_Barlow").text,
    "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "Helen Frankenthaler": wiki_wiki.page("Helen_Frankenthaler").text,
    "Sandy Skoglund": wiki_wiki.page("Sandy_Skoglund").text,
    "Sophie Calle": wiki_wiki.page("Sophie_Calle").text,
    "Saskia Sassen": wiki_wiki.page("Saskia_Sassen").text,
    "Alicia Henry": wiki_wiki.page("Alicia_Henry").text,
    "Sarah Lucas": wiki_wiki.page("Sarah_Lucas").text,
    "Lynne Cohen": wiki_wiki.page("Lynne_Cohen").text,
    "Monique Prieto": wiki_wiki.page("Monique_Prieto").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Joan Baez": wiki_wiki.page("Joan_Baez").text,
    "Patty Jenkins": wiki_wiki.page("Patty_Jenkins").text,
    "Rashid Johnson": wiki_wiki.page("Rashid_Johnson").text,
    "Amy Sherald": wiki_wiki.page("Amy_Sherald").text,
    "Carrie Mae Weems": wiki_wiki.page("Carrie_Mae_Weems").text,
    "Francesco Clemente": wiki_wiki.page("Francesco_Clemente").text,
    "Alice Neel": wiki_wiki.page("Alice_Neel").text,
    "Kimsooja": wiki_wiki.page("Kimsooja").text,
    "Tina Modotti": wiki_wiki.page("Tina_Modotti").text,
    "Joan Mitchell": wiki_wiki.page("Joan_Mitchell").text,
    "Doris Salcedo": wiki_wiki.page("Doris_Salcedo").text,
    "Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
    "Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
    "Ai Weiwei": wiki_wiki.page("Ai_Weiwei").text,
    "Zhang Xiaogang": wiki_wiki.page("Zhang_Xiaogang").text,
    "Xu Bing": wiki_wiki.page("Xu_Bing").text,
    "Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
    "Hiroshi Sugimoto": wiki_wiki.page("Hiroshi_Sugimoto").text,
    "Ryoji Ikeda": wiki_wiki.page("Ryoji_Ikeda").text,
    "Tatsuo Miyajima": wiki_wiki.page("Tatsuo_Miyajima").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Isamu Noguchi": wiki_wiki.page("Isamu_Noguchi").text,
    "Lee Ufan": wiki_wiki.page("Lee_Ufan").text,
    "Wang Guangyi": wiki_wiki.page("Wang_Guangyi").text,
    "Zhang Huan": wiki_wiki.page("Zhang_Huan").text,
    "Mao Lizi": wiki_wiki.page("Mao_Lizi").text,
    "Gu Wenda": wiki_wiki.page("Gu_Wenda").text,
    "Cai Guo-Qiang": wiki_wiki.page("Cai_Guo-Qiang").text,
    "Jiang Zhi": wiki_wiki.page("Jiang_Zhi").text,
    "Fang Lijun": wiki_wiki.page("Fang_Lijun").text,
    "Dong Chiu": wiki_wiki.page("Dong_Chiu").text,
    "Huang Yong Ping": wiki_wiki.page("Huang_Yong_Ping").text,
    "Chen Wenling": wiki_wiki.page("Chen_Wenling").text,
    "Yang Fudong": wiki_wiki.page("Yang_Fudong").text,
    "Katsushika Hokusai": wiki_wiki.page("Katsushika_Hokusai").text,
    "Utagawa Hiroshige": wiki_wiki.page("Utagawa_Hiroshige").text,
    "Yuki Onodera": wiki_wiki.page("Yuki_Onodera").text,
    "Junko Chodos": wiki_wiki.page("Junko_Chodos").text,
    "Sudarshan Shetty": wiki_wiki.page("Sudarshan_Shetty").text,
    "Subodh Gupta": wiki_wiki.page("Subodh_Gupta").text,
    "Anish Kapoor": wiki_wiki.page("Anish_Kapoor").text,
    "Bharti Kher": wiki_wiki.page("Bharti_Kher").text,
    "Raqib Shaw": wiki_wiki.page("Raqib_Shaw").text,
    "Madhvi Parekh": wiki_wiki.page("Madhvi_Parekh").text,
    "Nikhil Chopra": wiki_wiki.page("Nikhil_Chopra").text,
    "Sudhir Patwardhan": wiki_wiki.page("Sudhir_Patwardhan").text,
    "Ravi Agarwal": wiki_wiki.page("Ravi_Agarwal").text,
    "Sohan Qadri": wiki_wiki.page("Sohan_Qadri").text,
    "Shilpa Gupta": wiki_wiki.page("Shilpa_Gupta").text,
    "Khaled Jarrar": wiki_wiki.page("Khaled_Jarrar").text,
    "Taysir Batniji": wiki_wiki.page("Taysir_Batniji").text,
    "Walid Raad": wiki_wiki.page("Walid_Raad").text,
    "Nadine Abdel Aziz": wiki_wiki.page("Nadine_Abdel_Aziz").text,
    "Monir Shahroudy Farmanfarmaian": wiki_wiki.page("Monir_Shahroudy_Farmanfarmaian").text,
    "Nina Katchadourian": wiki_wiki.page("Nina_Katchadourian").text,
    "Zaha Hadid": wiki_wiki.page("Zaha_Hadid").text,
    "Shoja Azari": wiki_wiki.page("Shoja_Azari").text,
    "Mohammad Ali Talpur": wiki_wiki.page("Mohammad_Ali_Talpur").text,
    "Jamil Naqsh": wiki_wiki.page("Jamil_Naqsh").text,
    "Feroze Ahmad": wiki_wiki.page("Feroze_Ahmad").text,
    "Madhusree Dey": wiki_wiki.page("Madhusree_Dey").text,
    "Maya Hayuk": wiki_wiki.page("Maya_Hayuk").text,
    "Tara Sabharwal": wiki_wiki.page("Tara_Sabharwal").text,
    "Ali Kazim": wiki_wiki.page("Ali_Kazim").text,
    "Anjum Shahzad": wiki_wiki.page("Anjum_Shahzad").text,
    "Asim Butt": wiki_wiki.page("Asim_Butt").text,
    "Rashid Rana": wiki_wiki.page("Rashid_Rana").text,
    "Imran Qureshi": wiki_wiki.page("Imran_Qureshi").text,
    "Saira Wasim": wiki_wiki.page("Saira_Wasim").text,
    "Shazia Sikander": wiki_wiki.page("Shazia_Sikander").text,
    "Suhail Malik": wiki_wiki.page("Suhail_Malik").text,
    "Tariq al-Azzawi": wiki_wiki.page("Tariq_al-Azzawi").text,
    "Ayman Baalbaki": wiki_wiki.page("Ayman_Baalbaki").text,
    "Bouthayna Al-Mohammad": wiki_wiki.page("Bouthayna_Al-Mohammad").text,
    "Hasan Ragab": wiki_wiki.page("Hasan_Ragab").text,
    "Nasser Al-Sayer": wiki_wiki.page("Nasser_Al-Sayer").text,
    "Huda Lutfi": wiki_wiki.page("Huda_Lutfi").text,
    "Mohamed Melehi": wiki_wiki.page("Mohamed_Melehi").text,
    "Khalil Chahine": wiki_wiki.page("Khalil_Chahine").text,
    "Randa Mdah": wiki_wiki.page("Randa_Mdah").text,
    "Mounir Fatmi": wiki_wiki.page("Mounir_Fatmi").text,
    "Samia Halaby": wiki_wiki.page("Samia_Halaby").text,
    "Zoulikha Bouabdellah": wiki_wiki.page("Zoulikha_Bouabdellah").text,
    "Shirin Neshat": wiki_wiki.page("Shirin_Neshat").text,
    "Ghada Amer": wiki_wiki.page("Ghada_Amer").text,
    "Nathalie Djurberg": wiki_wiki.page("Nathalie_Djurberg").text,
    "Sami Al-Taher": wiki_wiki.page("Sami_Al-Taher").text,
    "Abdoulaye Konaté": wiki_wiki.page("Abdoulaye_Konaté").text,
    "Wissam Shawkat": wiki_wiki.page("Wissam_Shawkat").text,
    "Nadia Kaabi-Linke": wiki_wiki.page("Nadia_Kaabi-Linke").text,
    "Mouna Karray": wiki_wiki.page("Mouna_Karray").text,
    "Hassan Ragab": wiki_wiki.page("Hassan_Ragab").text,
    "Mohammed Kazem": wiki_wiki.page("Mohammed_Kazem").text,
    "Lalla Essaydi": wiki_wiki.page("Lalla_Essaydi").text,
    "Olfa Feki": wiki_wiki.page("Olfa_Feki").text,
    "Khaled Jarrar": wiki_wiki.page("Khaled_Jarrar").text,
    "Alia Ali": wiki_wiki.page("Alia_Ali").text,
    "Iman Issa": wiki_wiki.page("Iman_Issa").text,
    "Ghada Amer": wiki_wiki.page("Ghada_Amer").text,
    "Rania Matar": wiki_wiki.page("Rania_Matar").text,
    "Samira Maatoug": wiki_wiki.page("Samira_Maatoug").text,
    "Bouchra Khalili": wiki_wiki.page("Bouchra_Khalili").text,
    "Wissam Shawkat": wiki_wiki.page("Wissam_Shawkat").text,
    "Omar Hassan": wiki_wiki.page("Omar_Hassan").text,
    "Mona Hatoum": wiki_wiki.page("Mona_Hatoum").text,
    "Zeinab Al Hashemi": wiki_wiki.page("Zeinab_Al_Hashemi").text,
    "Malak Helmy": wiki_wiki.page("Malak_Helmy").text,
    "Fatima Al Qadiri": wiki_wiki.page("Fatima_Al_Qadiri").text,
    "Ali Kazim": wiki_wiki.page("Ali_Kazim").text,
    "Sanaa Ghalia": wiki_wiki.page("Sanaa_Ghalia").text,
    "Yahya Alnasir": wiki_wiki.page("Yahya_Alnasir").text,
    "Mona Zaki": wiki_wiki.page("Mona_Zaki").text,
    "Eslam Othman": wiki_wiki.page("Eslam_Othman").text,
    "Khaled Taha": wiki_wiki.page("Khaled_Taha").text,
    "Mona AlIssa": wiki_wiki.page("Mona_AlIssa").text,
    "Maha Maamoun": wiki_wiki.page("Maha_Maamoun").text,
    "Ziad Antar": wiki_wiki.page("Ziad_Antar").text,
    "Sami Zayn": wiki_wiki.page("Sami_Zayn").text,
    "Zahran Al-Hajri": wiki_wiki.page("Zahran_Al-Hajri").text,
    "Fatimah Tuggar": wiki_wiki.page("Fatimah_Tuggar").text,
    "Amina Benbouchta": wiki_wiki.page("Amina_Benbouchta").text,
    "Khalil Rabah": wiki_wiki.page("Khalil_Rabah").text,
    "Sanaa Benavides": wiki_wiki.page("Sanaa_Benavides").text,
    "Wissam Shawkat": wiki_wiki.page("Wissam_Shawkat").text,
    "Laila Shereen": wiki_wiki.page("Laila_Shereen").text,
    "Khaled Jarrar": wiki_wiki.page("Khaled_Jarrar").text,
    "Rania Matar": wiki_wiki.page("Rania_Matar").text,
    "Omar Abdelkafi": wiki_wiki.page("Omar_Abdelkafi").text,
    "Zahra Al Zayn": wiki_wiki.page("Zahra_Al_Zayn").text,
    "Hassan Hajjaj": wiki_wiki.page("Hassan_Hajjaj").text,
    "Mona Hatoum": wiki_wiki.page("Mona_Hatoum").text,
    "Sahar Khraibani": wiki_wiki.page("Sahar_Khraibani").text,
    "Maha Maamoun": wiki_wiki.page("Maha_Maamoun").text,
    "Taysir Batniji": wiki_wiki.page("Taysir_Batniji").text,
    "Khalil Rabah": wiki_wiki.page("Khalil_Rabah").text,
    "Khaled Nasr": wiki_wiki.page("Khaled_Nasr").text,
    "Michaela Maccaferri": wiki_wiki.page("Michaela_Maccaferri").text,
    "Fouad Elkoury": wiki_wiki.page("Fouad_Elkoury").text,
    "Alia Ali": wiki_wiki.page("Alia_Ali").text,
    "Mona Zaki": wiki_wiki.page("Mona_Zaki").text,
    "Nadine Toukan": wiki_wiki.page("Nadine_Toukan").text,
    "Rania Hammad": wiki_wiki.page("Rania_Hammad").text,
    "Younes Baba-Ali": wiki_wiki.page("Younes_Baba-Ali").text,
    "Yassine Belkessam": wiki_wiki.page("Yassine_Belkessam").text,
    "Rachid Koraïchi": wiki_wiki.page("Rachid_Koraïchi").text,
    "Samira Maatoug": wiki_wiki.page("Samira_Maatoug").text,
    "Mustafa Sabbagh": wiki_wiki.page("Mustafa_Sabbagh").text,
    "Tarek Atoui": wiki_wiki.page("Tarek_Atoui").text,
    "Mohammed Kazem": wiki_wiki.page("Mohammed_Kazem").text,
    "Khalil Chahine": wiki_wiki.page("Khalil_Chahine").text,
    "Ahmed Mater": wiki_wiki.page("Ahmed_Mater").text,
    "Tariq Al Azzawi": wiki_wiki.page("Tariq_Al_Azzawi").text,
    "Samia Halaby": wiki_wiki.page("Samia_Halaby").text,
    "Bouchra Khalili": wiki_wiki.page("Bouchra_Khalili").text,
    "Taha Belal": wiki_wiki.page("Taha_Belal").text,
    "Fatimah Tuggar": wiki_wiki.page("Fatimah_Tuggar").text,
    "Ayman Baalbaki": wiki_wiki.page("Ayman_Baalbaki").text,
    "Omar Hassan": wiki_wiki.page("Omar_Hassan").text,
    "Samia Sadeq": wiki_wiki.page("Samia_Sadeq").text,
    "Khaled Al Saai": wiki_wiki.page("Khaled_Al_Saai").text,
    "Samar Martha": wiki_wiki.page("Samar_Martha").text,
    "Iman Issa": wiki_wiki.page("Iman_Issa").text,
    "Alaa Eddine Al-Maazouz": wiki_wiki.page("Alaa_Eddine_Al-Maazouz").text,
    "Rasha Salti": wiki_wiki.page("Rasha_Salti").text,
    "Ayman Abdel Wahab": wiki_wiki.page("Ayman_Abdel_Wahab").text,
    "Ziad Antar": wiki_wiki.page("Ziad_Antar").text,
    "Sami Al-Taher": wiki_wiki.page("Sami_Al-Taher").text,
    "Mouna Karray": wiki_wiki.page("Mouna_Karray").text,
    "Najla El Zein": wiki_wiki.page("Najla_El_Zein").text,
    "Farid Belkahia": wiki_wiki.page("Farid_Belkahia").text,
    "Rania Hammad": wiki_wiki.page("Rania_Hammad").text,
    "Fouad Anid": wiki_wiki.page("Fouad_Anid").text,
    "Fayçal Jebali": wiki_wiki.page("Fayçal_Jebali").text,
       "Marina Abramović": wiki_wiki.page("Marina_Abramović").text,
    "Ai Weiwei": wiki_wiki.page("Ai_Weiwei").text,
    "Banksy": wiki_wiki.page("Banksy").text,
    "Jeff Koons": wiki_wiki.page("Jeff_Koons").text,
    "Damien Hirst": wiki_wiki.page("Damien_Hirst").text,
    "David Hockney": wiki_wiki.page("David_Hockney").text,
    "Gerhard Richter": wiki_wiki.page("Gerhard_Richter").text,
    "Anselm Kiefer": wiki_wiki.page("Anselm_Kiefer").text,
    "Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
    "Frida Kahlo": wiki_wiki.page("Frida_Kahlo").text,
    "Salvador Dalí": wiki_wiki.page("Salvador_Dalí").text,
    "Pablo Picasso": wiki_wiki.page("Pablo_Picasso").text,
    "Claude Monet": wiki_wiki.page("Claude_Monet").text,
    "Vincent van Gogh": wiki_wiki.page("Vincent_van_Gogh").text,
    "Leonardo da Vinci": wiki_wiki.page("Leonardo_da_Vinci").text,
    "Andy Warhol": wiki_wiki.page("Andy_Warhol").text,
    "Jackson Pollock": wiki_wiki.page("Jackson_Pollock").text,
    "Roy Lichtenstein": wiki_wiki.page("Roy_Lichtenstein").text,
    "Keith Haring": wiki_wiki.page("Keith_Haring").text,
    "Jean-Michel Basquiat": wiki_wiki.page("Jean-Michel_Basquiat").text,
    "Lucian Freud": wiki_wiki.page("Lucian_Freud").text,
    "Marcel Duchamp": wiki_wiki.page("Marcel_Duchamp").text,
    "Edward Hopper": wiki_wiki.page("Edward_Hopper").text,
    "Rene Magritte": wiki_wiki.page("Rene_Magritte").text,
    "Francis Bacon": wiki_wiki.page("Francis_Bacon").text,
    "Henri Matisse": wiki_wiki.page("Henri_Matisse").text,
    "Paul Cézanne": wiki_wiki.page("Paul_Cézanne").text,
    "Georges Braque": wiki_wiki.page("Georges_Braque").text,
    "Marc Chagall": wiki_wiki.page("Marc_Chagall").text,
    "Edgar Degas": wiki_wiki.page("Edgar_Degas").text,
    "Egon Schiele": wiki_wiki.page("Egon_Schiele").text,
    "Sandro Botticelli": wiki_wiki.page("Sandro_Botticelli").text,
    "Caravaggio": wiki_wiki.page("Caravaggio").text,
    "Michelangelo": wiki_wiki.page("Michelangelo").text,
    "Rembrandt": wiki_wiki.page("Rembrandt").text,
    "Gustav Klimt": wiki_wiki.page("Gustav_Klimt").text,
    "Henri Toulouse-Lautrec": wiki_wiki.page("Henri_Toulouse-Lautrec").text,
    "Edvard Munch": wiki_wiki.page("Edvard_Munch").text,
    "Albrecht Dürer": wiki_wiki.page("Albrecht_Dürer").text,
    "Jan van Eyck": wiki_wiki.page("Jan_van_Eyck").text,
    "Hieronymus Bosch": wiki_wiki.page("Hieronymus_Bosch").text,
    "Diego Velázquez": wiki_wiki.page("Diego_Velázquez").text,
    "El Greco": wiki_wiki.page("El_Greco").text,
    "Paul Gauguin": wiki_wiki.page("Paul_Gauguin").text,
    "Hiroshi Sugimoto": wiki_wiki.page("Hiroshi_Sugimoto").text,
    "Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
    "Mariko Mori": wiki_wiki.page("Mariko_Mori").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Taro Okamoto": wiki_wiki.page("Taro_Okamoto").text,
    "Kazuo Shiraga": wiki_wiki.page("Kazuo_Shiraga").text,
    "Yayoi Kusama": wiki_wiki.page("Yayoi_Kusama").text,
    "Ai Weiwei": wiki_wiki.page("Ai_Weiwei").text,
    "Kazuo Ishiguro": wiki_wiki.page("Kazuo_Ishiguro").text,
    "Takashi Murakami": wiki_wiki.page("Takashi_Murakami").text,
    "Hiroshi Sugimoto": wiki_wiki.page("Hiroshi_Sugimoto").text,
    "Ryoji Ikeda": wiki_wiki.page("Ryoji_Ikeda").text,
    "Yoko Ono": wiki_wiki.page("Yoko_Ono").text,
    "Eiko Ishioka": wiki_wiki.page("Eiko_Ishioka").text,
    "Shigeru Ban": wiki_wiki.page("Shigeru_Ban").text,
    "Kengo Kuma": wiki_wiki.page("Kengo_Kuma").text,
    "Tadao Ando": wiki_wiki.page("Tadao_Ando").text,
    "Kiyoshi Kuromiya": wiki_wiki.page("Kiyoshi_Kuromiya").text,
    "Isamu Noguchi": wiki_wiki.page("Isamu_Noguchi").text



    
    
}

# 📌 Metin dosyasına kaydediyoruz
with open("sanatcilar_biyografi.txt", "w", encoding="utf-8") as file:
    for sanatci, biyografi in sanatci_listesi.items():
        if biyografi.strip():  # Boş içerikleri kontrol edelim
            file.write(f"--- {sanatci} ---\n{biyografi}\n\n")

print("Sanatçı biyografileri 'sanatcilar_biyografi.txt' dosyasına kaydedildi! 🎨")
# Out:
# Sanatçı biyografileri 'sanatcilar_biyografi.txt' dosyasına kaydedildi! 🎨
